# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2
from sklearn.model_selection import ParameterGrid
from tqdm import tqdm
import itertools

# %%
def denoise_image(image, filters):
    '''
    filters=[
        {name:filter1
            n_iter:...,
            params:{
                ...
            }
        },
        {name:filter2
            n_iter:...,
            params:{
                ...
            }
        },
        ...
    ]
    '''
    # print(f"Denoise filters = {filters}")
    for filter in filters:
        for _ in range(filter['n_iter']):
            match filter['name']:
                case "mean":
                    '''
                    {"ksize" : 15}
                    '''
                    k_size = filter['ksize']
                    mean_kernel = np.ones([k_size, k_size])/(k_size**2)
                    image = cv2.filter2D(image, -1, mean_kernel)

                case "median":
                    '''
                    {"ksize" : 11}
                    '''
                    image = cv2.medianBlur(image, filter['ksize'])

                case "bilateral":
                    '''
                    {"d" : 3,
                    "sigmaColor" : 2,
                    "sigmaSpace" : 1.5}
                    '''
                    image = cv2.bilateralFilter(
                        image, d=filter['d'], sigmaColor=filter['sigmaColor'], sigmaSpace=filter['sigmaSpace'])

                case 'gaussian':
                    '''
                    {"sigmaX" : 2}
                    '''
                    sigmaX = filter['sigmaX']
                    ksize = 2*int(np.ceil(3*sigmaX)) + 1
                    image = cv2.GaussianBlur(image, (ksize, ksize), sigmaX)

                # case 'non_local_means':
                #     '''
                #     {'templateWindowSize':5,"searchWindowSize":21, "h":3, "hColor": 20}
                #     '''
                #     image = cv2.fastNlMeansDenoisingColored(
                #         image, **filter['params'])

                # case 'canny':
                #     '''
                #     {'threshold1':5,"threshold2":21}
                #     '''
                #     image = cv2.Canny(image, **filter['params'])

                # case "adaptive":
                #     channel1 = image[:, :, 0]
                #     channel2 = image[:, :, 1]
                #     channel3 = image[:, :, 2]
                #     image[:, :, 0] = adaptive_approach(channel1)
                #     image[:, :, 1] = adaptive_approach(channel2)
                #     image[:, :, 2] = adaptive_approach(channel3)

                case 'sharpen':
                    kernel = np.array([[0, -1, 0],
                                       [-1, 5, -1],
                                       [0, -1, 0]])
                    image = cv2.filter2D(image, -1, kernel=kernel)

                case 'emboss':
                    kernel = np.array([[-2, -1, 0],
                                       [-1, 1, 1],
                                       [0, 1, 2]])
                    image = cv2.filter2D(image, -1, kernel=kernel)
                case _: pass
    return image

# %%
''' 
USA SOLO I FILTRI NELLA LISTA E ITERA SOLO SU ORDINE E NUMERO DI ITERAZIONI + ALTRI PARAMETRI
'''
from itertools import product
from skimage.metrics import structural_similarity as ssim

def rmse(img1, img2):
    rmse_score = np.sqrt(np.mean((img1 - img2) ** 2))
    return rmse_score

def psnr(img1, img2):
    mse = np.mean((img1 - img2) ** 2)
    if mse == 0:
        return float('inf')
    max_pixel = 255.0
    psnr_score = 20 * np.log10(max_pixel / np.sqrt(mse))
    return psnr_score

def cross_correlation(img1, img2):
    img1_norm = (img1 - np.mean(img1)) / np.std(img1)
    img2_norm = (img2 - np.mean(img2)) / np.std(img2)
    corr_coeff = np.mean(img1_norm * img2_norm)
    return corr_coeff

def mae(img1, img2):
    abs_diff = np.abs(img1 - img2)
    mae_score = np.mean(abs_diff)
    return mae_score

def generate_order_permutations(dict_list):
    order_permutations = []
    dict_count = len(dict_list)
    
    # Generate all permutations of the indices of the dictionaries
    for permutation in itertools.permutations(range(dict_count)):
        permuted_list = [dict_list[i] for i in permutation]
        order_permutations.append(permuted_list)
    
    return order_permutations

def calculate_total_iterations(permutazioni):
    total_iterations = 0
    for permutation in permutazioni:
        for filt in permutation:
            #n_iter = len(filt['n_iter'])
            param_combinations_count = len(list(ParameterGrid(filt)))
            total_iterations += param_combinations_count
            # print(f"In permutazione {filt}: {n_iter * param_combinations_count}")
    return total_iterations*len(permutazioni)


def find_best_params(noisy_image_path:str, 
                     denoised_image_path:str, 
                     filters:list
                     ) :
    # Leggo le immagini 

    input_image = cv2.imread(noisy_image_path,cv2.IMREAD_GRAYSCALE)
    input_image_denoised = cv2.imread(denoised_image_path,cv2.IMREAD_GRAYSCALE)  
    
    # Per ogni possibile permutazione dei filtri richiesti
    permutazioni = generate_order_permutations(filters)
    
    # Calcola il numero totale di iterazioni
    total_iterations = calculate_total_iterations(permutazioni)

    # Prova tutte le possibili combinazioni di parametri
    best_score = float('-inf')
    best_params = None
    # with tqdm(total=total_iterations, desc="Testing Combinations") as pbar:
    for param_grids in permutazioni:
        combinations = {f"{i}":[*ParameterGrid(param_grids[i])] for i in range(len(param_grids))}
        
        # Ottieni le liste di elementi per ogni chiave e crea una lista di tuple di elementi
        lists_of_elements = [combinations[key] for key in combinations]            
        combinations_list = [*product(*lists_of_elements)]

        # Stampa le combinazioni
        for combo in combinations_list:
            filtered_image = denoise_image(input_image, list(combo))
        
            # Calcola una qualche metrica di qualità dell'immagine filtrata, ad esempio l'errore quadratico medio
            """
            SCEGLI QUALE SCORE USARE
            """
            # score = np.mean((input_image_denoised - filtered_image) ** 2)
            # score = np.linalg.norm((input_image_denoised - filtered_image))
            score= ssim(input_image_denoised, filtered_image,data_range=filtered_image.max()-filtered_image.min())
            # score = psnr(input_image_denoised, filtered_image)
            # score = cross_correlation(input_image_denoised, filtered_image)
            # score = mae(input_image_denoised, filtered_image)
            # score = rmse(input_image_denoised, filtered_image)
            
            
            # Aggiorna i parametri se otteniamo una migliore qualità dell'immagine filtrata
            if score > best_score:
                best_score = score
                best_params = list(combo)
                print(score,combo)
                # Aggiorna la barra di avanzamento
                # pbar.update(1)

    print("Migliori parametri:", best_params)

    # Applica il bilateral filtering con i migliori parametri
    filtered_image = denoise_image(input_image, best_params)

    # Visualizza l'immagine filtrata
    plt.figure(figsize=(20,20))
    plt.subplot(131); plt.imshow(input_image[:,:,::-1]); plt.title("Input Image")
    plt.subplot(132); plt.imshow(input_image_denoised[:,:,::-1]); plt.title("Perfectly-denoised Image")
    plt.subplot(133); plt.imshow(filtered_image[:,:,::-1]); plt.title("Filtered Image")
    plt.show()

    # Visualizza errore
    plt.figure(figsize=(10,10))
    plt.imshow(abs(input_image[:,:,::-1]-filtered_image[:,:,::-1])); plt.title("Filtering error")
    
    return best_params

# %%
path_noised = "scene4.png"
path_DEnoised = "scene4_denoised_online.png"

best_params = find_best_params(
    noisy_image_path=path_noised,
    denoised_image_path=path_DEnoised,
    filters=[
        {   
           "name": ["median"],
           "n_iter": [*range(0,3)],  # Modifica qui, avvolgi il valore in una lista
           "ksize": [*range(3, 9, 2)]
        },
        {   
           "name": ["bilateral"],
           "n_iter": [*range(1,2)],  # Modifica qui, avvolgi il valore in una lista
           "d": [*range(5, 9, 2)],
           'sigmaColor':[*range(10,150,30)],
           'sigmaSpace':[*range(10,150,30)]
        },
        {   
           "name": ["median"],
           "n_iter": [*range(0,3)],  # Modifica qui, avvolgi il valore in una lista
           "ksize": [*range(3, 9, 2)]
        },
    ]
)
# Out:
# 0.11707667377731737 ({'ksize': 3, 'n_iter': 0, 'name': 'median'}, {'d': 5, 'n_iter': 1, 'name': 'bilateral', 'sigmaColor': 10, 'sigmaSpace': 10}, {'ksize': 3, 'n_iter': 0, 'name': 'median'})
# 0.27959411828031666 ({'ksize': 3, 'n_iter': 0, 'name': 'median'}, {'d': 5, 'n_iter': 1, 'name': 'bilateral', 'sigmaColor': 10, 'sigmaSpace': 10}, {'ksize': 3, 'n_iter': 1, 'name': 'median'})
# 0.3612969631619195 ({'ksize': 3, 'n_iter': 0, 'name': 'median'}, {'d': 5, 'n_iter': 1, 'name': 'bilateral', 'sigmaColor': 10, 'sigmaSpace': 10}, {'ksize': 3, 'n_iter': 2, 'name': 'median'})
# 0.4036896027145317 ({'ksize': 3, 'n_iter': 0, 'name': 'median'}, {'d': 5, 'n_iter': 1, 'name': 'bilateral', 'sigmaColor': 10, 'sigmaSpace': 10}, {'ksize': 5, 'n_iter': 1, 'name': 'median'})
# 0.5279627657038046 ({'ksize': 3, 'n_iter': 0, 'name': 'median'}, {'d': 5, 'n_iter': 1, 'name': 'bilateral', 'sigmaColor': 10, 'sigmaSpace': 10}, {'ksize': 5, 'n_iter': 2, 'name': 'median'})
# 0.5942342109056715 ({'ksize': 3, 'n_iter': 0, 'name': 'median'}, {'d': 5, 'n_iter': 1, 'name': 'bilateral', 'sigmaColor': 10, 'sigmaSpace': 10}, {'ksize': 7, 'n_iter': 2, 'name': 'median'})
# 0.6234933963931323 ({'ksize': 3, 'n_iter': 0, 'name': 'median'}, {'d': 5, 'n_iter': 1, 'name': 'bilateral', 'sigmaColor': 40, 'sigmaSpace': 10}, {'ksize': 7, 'n_iter': 2, 'name': 'median'})
# 0.6235759955954715 ({'ksize': 3, 'n_iter': 0, 'name': 'median'}, {'d': 5, 'n_iter': 1, 'name': 'bilateral', 'sigmaColor': 40, 'sigmaSpace': 40}, {'ksize': 7, 'n_iter': 2, 'name': 'median'})
# 0.6235779198063515 ({'ksize': 3, 'n_iter': 0, 'name': 'median'}, {'d': 5, 'n_iter': 1, 'name': 'bilateral', 'sigmaColor': 40, 'sigmaSpace': 70}, {'ksize': 7, 'n_iter': 2, 'name': 'median'})
# 0.6235785260913564 ({'ksize': 3, 'n_iter': 0, 'name': 'median'}, {'d': 5, 'n_iter': 1, 'name': 'bilateral', 'sigmaColor': 40, 'sigmaSpace': 130}, {'ksize': 7, 'n_iter': 2, 'name': 'median'})
# 0.6261778979937408 ({'ksize': 3, 'n_iter': 0, 'name': 'median'}, {'d': 7, 'n_iter': 1, 'name': 'bilateral', 'sigmaColor': 40, 'sigmaSpace': 10}, {'ksize': 7, 'n_iter': 2, 'name': 'median'})
# 0.6262140333359705 ({'ksize': 3, 'n_iter': 0, 'name': 'median'}, {'d': 7, 'n_iter': 1, 'name': 'bilateral', 'sigmaColor': 40, 'sigmaSpace': 40}, {'ksize': 7, 'n_iter': 2, 'name': 'median'})
# 0.6262196295317037 ({'ksize': 3, 'n_iter': 0, 'name': 'median'}, {'d': 7, 'n_iter': 1, 'name': 'bilateral', 'sigmaColor': 40, 'sigmaSpace': 70}, {'ksize': 7, 'n_iter': 2, 'name': 'median'})
# 0.6262213546287466 ({'ksize': 3, 'n_iter': 0, 'name': 'median'}, {'d': 7, 'n_iter': 1, 'name': 'bilateral', 'sigmaColor': 40, 'sigmaSpace': 100}, {'ksize': 7, 'n_iter': 2, 'name': 'median'})
# 0.626222899366062 ({'ksize': 3, 'n_iter': 0, 'name': 'median'}, {'d': 7, 'n_iter': 1, 'name': 'bilateral', 'sigmaColor': 40, 'sigmaSpace': 130}, {'ksize': 7, 'n_iter': 2, 'name': 'median'})
# 0.6283888794628607 ({'ksize': 3, 'n_iter': 1, 'name': 'median'}, {'d': 5, 'n_iter': 1, 'name': 'bilateral', 'sigmaColor': 40, 'sigmaSpace': 10}, {'ksize': 7, 'n_iter': 2, 'name': 'median'})
# 0.6284249388758234 ({'ksize': 3, 'n_iter': 1, 'name': 'median'}, {'d': 5, 'n_iter': 1, 'name': 'bilateral', 'sigmaColor': 40, 'sigmaSpace': 40}, {'ksize': 7, 'n_iter': 2, 'name': 'median'})
# 0.6284258287490334 ({'ksize': 3, 'n_iter': 1, 'name': 'median'}, {'d': 5, 'n_iter': 1, 'name': 'bilateral', 'sigmaColor': 40, 'sigmaSpace': 100}, {'ksize': 7, 'n_iter': 2, 'name': 'median'})
# 0.6284261906132048 ({'ksize': 3, 'n_iter': 1, 'name': 'median'}, {'d': 5, 'n_iter': 1, 'name': 'bilateral', 'sigmaColor': 40, 'sigmaSpace': 130}, {'ksize': 7, 'n_iter': 2, 'name': 'median'})
# 0.6295180171080698 ({'ksize': 3, 'n_iter': 1, 'name': 'median'}, {'d': 5, 'n_iter': 1, 'name': 'bilateral', 'sigmaColor': 70, 'sigmaSpace': 10}, {'ksize': 7, 'n_iter': 2, 'name': 'median'})
# 0.6295539731798514 ({'ksize': 3, 'n_iter': 1, 'name': 'median'}, {'d': 5, 'n_iter': 1, 'name': 'bilateral', 'sigmaColor': 70, 'sigmaSpace': 40}, {'ksize': 7, 'n_iter': 2, 'name': 'median'})
# 0.629558896514245 ({'ksize': 3, 'n_iter': 1, 'name': 'median'}, {'d': 5, 'n_iter': 1, 'name': 'bilateral', 'sigmaColor': 70, 'sigmaSpace': 70}, {'ksize': 7, 'n_iter': 2, 'name': 'median'})
# 0.6295612164049053 ({'ksize': 3, 'n_iter': 1, 'name': 'median'}, {'d': 5, 'n_iter': 1, 'name': 'bilateral', 'sigmaColor': 70, 'sigmaSpace': 100}, {'ksize': 7, 'n_iter': 2, 'name': 'median'})
# 0.6295617976665502 ({'ksize': 3, 'n_iter': 1, 'name': 'median'}, {'d': 5, 'n_iter': 1, 'name': 'bilateral', 'sigmaColor': 70, 'sigmaSpace': 130}, {'ksize': 7, 'n_iter': 2, 'name': 'median'})
# 0.6338238203556508 ({'ksize': 3, 'n_iter': 1, 'name': 'median'}, {'d': 7, 'n_iter': 1, 'name': 'bilateral', 'sigmaColor': 40, 'sigmaSpace': 10}, {'ksize': 7, 'n_iter': 2, 'name': 'median'})
# 0.6339410023661279 ({'ksize': 3, 'n_iter': 1, 'name': 'median'}, {'d': 7, 'n_iter': 1, 'name': 'bilateral', 'sigmaColor': 40, 'sigmaSpace': 40}, {'ksize': 7, 'n_iter': 2, 'name': 'median'})
# 0.6339475282750998 ({'ksize': 3, 'n_iter': 1, 'name': 'median'}, {'d': 7, 'n_iter': 1, 'name': 'bilateral', 'sigmaColor': 40, 'sigmaSpace': 70}, {'ksize': 7, 'n_iter': 2, 'name': 'median'})
# 0.6339485052257633 ({'ksize': 3, 'n_iter': 1, 'name': 'median'}, {'d': 7, 'n_iter': 1, 'name': 'bilateral', 'sigmaColor': 40, 'sigmaSpace': 100}, {'ksize': 7, 'n_iter': 2, 'name': 'median'})
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 4
#       1 path_noised = "scene4.png"
#       2 path_DEnoised = "scene4_denoised_online.png"
# ----> 4 best_params = find_best_params(
#       5     noisy_image_path=path_noised,
#       6     denoised_image_path=path_DEnoised,
#       7     filters=[
#       8         {
#       9            "name": ["median"],
#      10            "n_iter": [*range(0,3)],  # Modifica qui, avvolgi il valore in una lista
#      11            "ksize": [*range(3, 9, 2)]
#      12         },
#      13         {
#      14            "name": ["bilateral"],
#      15            "n_iter": [*range(1,2)],  # Modifica qui, avvolgi il valore in una lista
#      16            "d": [*range(5, 9, 2)],
#      17            'sigmaColor':[*range(10,150,30)],
#      18            'sigmaSpace':[*range(10,150,30)]
#      19         },
#      20         {
#      21            "name": ["median"],
#      22            "n_iter": [*range(0,3)],  # Modifica qui, avvolgi il valore in una lista
#      23            "ksize": [*range(3, 9, 2)]
#      24         },
#      25     ]
#      26 )
#
# Cell In[3], line 80, in find_best_params(noisy_image_path, denoised_image_path, filters)
#      78 # Stampa le combinazioni
#      79 for combo in combinations_list:
# ---> 80     filtered_image = denoise_image(input_image, list(combo))
#      82     # Calcola una qualche metrica di qualità dell'immagine filtrata, ad esempio l'errore quadratico medio
#      83     """
#      84     SCEGLI QUALE SCORE USARE
#      85     """
#
# Cell In[2], line 35, in denoise_image(image, filters)
#      31 case "median":
#      32     '''
#      33     {"ksize" : 11}
#      34     '''
# ---> 35     image = cv2.medianBlur(image, filter['ksize'])
#      37 case "bilateral":
#      38     '''
#      39     {"d" : 3,
#      40     "sigmaColor" : 2,
#      41     "sigmaSpace" : 1.5}
#      42     '''
#
# KeyboardInterrupt:

# %%
print(best_params)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 print(best_params)
#
# NameError: name 'best_params' is not defined
